# %%
# !pip install accelerate

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

# %%
model_path = 'm-a-p/neo_7b'

tokenizer = AutoTokenizer.from_pretrained(model_path, use_fast=False, trust_remote_code=True)

model = AutoModelForCausalLM.from_pretrained(
    model_path,
    device_map="auto",
    torch_dtype='auto'
).eval()
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# model.safetensors.index.json:   0%|          | 0.00/21.0k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.85G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/4.91G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/848M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# WARNING:root:Some parameters are on the meta device device because they were offloaded to the cpu.

# %%
input_text = "what is Large Language Model?"

input_ids = tokenizer(input_text, add_generation_prompt=True, return_tensors='pt').to(model.device)
output_ids = model.generate(**input_ids, max_new_tokens=100)
response = tokenizer.decode(output_ids[0], skip_special_tokens=True)

print(response)
# Out:
# Keyword arguments {'add_generation_prompt': True} not recognized.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# what is Large Language Model?
#
# A large language model is a type of artificial intelligence that is trained on a vast amount of text data. It is designed to understand and generate human-like text, and can be used for a variety of tasks, such as translation, summarization, and question answering.
#
# What are the benefits of using a large language model?
#
# Using a large language model can provide several benefits, including:
#
# - Improved accuracy: Large language models are trained on a vast amount of
